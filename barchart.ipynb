# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("./styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#
#
#
#
#   @import url('https://fonts.googleapis.com/css?family=Bitter');
#   @import url('https://fonts.googleapis.com/css?family=Inconsolata');
#   @import url('https://fonts.googleapis.com/css?family=Chivo');
#   @import url('https://fonts.googleapis.com/css?family=Cousine');
#
#
#   div.cell{ width:auto;}
#
#   //div#notebook-container.container { width: 90%;}
#
#   #notebook-container { background-color: #fdfdfd;}
#
# .rendered_html th, td {
#   border: none;
#   border: 1px solid #dddddd !important;
#   line-height: 1.4;
#   font-family: Cousine;
#   letter-spacing: .5px;
#   color: #2a2a2a;
# }
#
#   div.text_cell_render h1,
#   div.text_cell_render h2,
#   div.text_cell_render h3,
#   div.text_cell_render h4,
#   div.text_cell_render h5,
#   div.text_cell_render h6 {
#       font-family: Chivo;
#       font-weight: 900;
#       color: #cc3700;
#       letter-spacing: 1px;
#   }
#
#   div.text_cell_render p, div.text_cell_render li {
#     font-family: Chivo;
#     font-size: 16px;
#     letter-spacing: .5px;
#   }
#
#
#
#
#
#   .CodeMirror {
#     background-color: #f1f1f1;
#     //background-image: linear-gradient(to bottom, hsl(200, 100%, 7%), hsl(200, 100%, 12%));
#
#     color: gray;
#     -webkit-filter: drop-shadow(2px 2px rgba(0,0,0,.1));
#
#   }
#
#   .CodeMirror pre{
#     font-family: Cousine;
#     font-size: 10pt;
#   }
#
#   .CodeMirror-lines { padding: 10px 20px 10px 20px;}
#
#   .cm-s-ipython span.cm-keyword { color: #e3655b;}
#
#   .cm-s-ipython span.cm-def { color: black;}
#
#   .cm-s-ipython span.cm-variable { color: #2F4F4F;}
#
#   .cm-s-ipython span.cm-string { color: #33A1C9;}
#
#   .cm-s-ipython span.cm-builtin { color: #2ecc40;}
#
#   .cm-s-ipython span.cm-comment { color: #9B8065;}
#
#
#
#
# </style>

# %% [markdown]
# *This is an initial dive into [Jupyter notebooks][jn], the self-contained Python environment.  The below post is [exported directly][ex] from [a Jupyter Notebook][nb].  The tables below each code block are the API responses.*
#
# *I am using the [BarChart.com OnDemand API][bc] to call getHistory() and receive up to 3 months of minute-level stock price data for a basket of stocks.*
#
# *Then I do bar analysis to find potential buy spots.  This analysis is simply counting instances of minutely bars closing on highs.*
#
# *After, I measure trends to find potential buy spots.  This analysis compares sequential bar highs/lows to assert trend reversals.*
#
# *To use the code yourself, you will need to setup a python environment, jupyter notebook or otherwise.  Then, you'll need to [request a free BarChart.com OnDemand API key][bc], and plug it into the code.*
#
# *Last, set the file path for your project directory, and in that folder create a folder 'Stock_Price_Data' to export data to, and a folder 'assets' for your list.  In 'assets' create an Excel file 'Watchlist'.  Starting in row 4 with the header, have names in the first column and tickers in the second column.*
#
# [jn]: https://jupyter.org/
# [ex]: https://github.com/jupyter/nbconvert
# [nb]: https://github.com/ale627/python/blob/master/barchart.ipynb
# [bc]: https://www.barchart.com/ondemand/free-market-data-api

# %% [markdown]
# # Fetch the data from BarChart
#
# Here we call the barchart getHistory API.  This is an adaptation of BlackArb's Python [tutorial][tut].
#
# #### Steps:
# - import libraries
# - set directories and API key
# - build URL to call API
# - get_minute_data() function
# - call the function
#
# **outputs: symbol, timestamp, tradingDay, open, high, low, close, volume, openInterest**
#
# [tut]: http://www.blackarbs.com/blog/how-to-get-free-intraday-stock-data-with-python-and-barcharts-ondemand-api/9/22/2015

# %%
# -*- coding: utf-8 -*-

#----------IMPORT LIBRARIES----------#
import time
t0 = time.clock()

import pandas as pd
from pandas.tseries.offsets import BDay

import numpy as np
import datetime as dt

from copy import copy
import warnings
warnings.filterwarnings('ignore',category=pd.io.pytables.PerformanceWarning)
 

    
#----------SET DIRECTORIES----------#
    
project_dir = r'C:\Users/drale/Desktop/python/' 
price_path = project_dir + r'Stock_Price_Data\\'

# header=3 to skip metadata   
spy_components = pd.read_excel(project_dir +\
                             'assets/Watchlist.xls', header=3)
syms = spy_components.Identifier.dropna()
syms = syms.drop(syms.index[-1]).sort_values()


apikey = '99f7186682f41a3bd739984105aef52a'



#----------BUILD URL----------#

def construct_barChart_url(sym, start_date, freq, api_key=apikey):
    '''Function to construct barchart api url'''
    
    url = 'http://marketdata.websol.barchart.com/getHistory.csv?' +\
            'key={}&symbol={}&type={}&startDate={}'.format(api_key, sym, freq, start_date)
    return url




#----------F(X) DEFINITION----------#

def get_minute_data():
    '''Function to Retrieve <= 3 months of minute data for SP500 components'''
    
    # YYYY MM DD HH MM SS
    start = '20171001000000'
    #end = d
    freq = 'minutes'    
    prices = {}
    symbol_count = len(syms)
    
    try:
        for i, sym in enumerate(syms, start=1):
            api_url = construct_barChart_url(sym, start, freq, api_key=apikey)
            try:
                csvfile = pd.read_csv(api_url, parse_dates=['timestamp'])
                csvfile.set_index('timestamp', inplace=True)
                prices[sym] = csvfile
            except:
                continue

            print('{}..[fetched] | {} of {} tickers |'.format(sym, i, symbol_count)) 
    except Exception as e: 
        print(e)
    finally:
        pass
    
    px = pd.Panel.from_dict(prices)
    px.major_axis = px.major_axis.tz_localize('utc').tz_convert('US/Pacific')
    return px



#----------CALL FUNCTION----------#

pxx = get_minute_data()
pxx



# timer
secs      = np.round( ( time.clock()  - t0 ), 4 )
time_secs = "{timeSecs} seconds to run".format(timeSecs = secs)
print( time_secs )
# Out:
# AAPL..[fetched] | 1 of 9 tickers |
# AMZN..[fetched] | 2 of 9 tickers |
# BIDU..[fetched] | 3 of 9 tickers |
# FB..[fetched] | 4 of 9 tickers |
# GOOGL..[fetched] | 5 of 9 tickers |
# GS..[fetched] | 6 of 9 tickers |
# IBB..[fetched] | 7 of 9 tickers |
# NFLX..[fetched] | 8 of 9 tickers |
# TSLA..[fetched] | 9 of 9 tickers |
# 44.0071 seconds to run

# %% [markdown]
# # Select stock
# Choose a ticker to analyze, and test the output.

# %%
stock = 'BIDU'

ohlc = pxx[stock]
ohlc.head(1)
# Out:
#                           symbol  tradingDay    open     high      low  \
# timestamp
# 2017-10-02 06:30:00-07:00   BIDU  2017-10-02  248.62  249.285  248.221
#
#                             close volume
# timestamp
# 2017-10-02 06:30:00-07:00  249.21  80053

# %% [markdown]
# # Accumulation
# Where 1 min candlestick closes on highs, flag as accumulated.

# %%
#create accum column: for closing on highs, assign 1
ohlc["accum"] = np.where(ohlc["high"] == ohlc["close"], 1, 0)

#list matches
accumulation_bars = ohlc[(ohlc.accum == 1)]
accumulation_bars[["high", "close", "accum"]].tail(3)
# Out:
#                              high   close  accum
# timestamp
# 2017-11-08 12:51:00-08:00  240.85  240.85      1
# 2017-11-08 12:52:00-08:00  241.08  241.08      1
# 2017-11-08 13:00:00-08:00  241.18  241.18      1

# %% [markdown]
# ## Two-in-a-row
# *Add the previous accumulated (or not) to current row*
#
# Measures when two 1-min candlesticks in a row close at highs.

# %%
#create conf column adding prev column
ohlc["conf"] = ohlc.accum + ohlc.accum.shift(1)

#where conf is 2, make a table
confirmation = ohlc[(ohlc.conf >= 2)]
confirmation[["high", "close", "conf"]].tail(3)
# Out:
#                              high   close  conf
# timestamp
# 2017-11-08 12:31:00-08:00  240.82  240.82     2
# 2017-11-08 12:32:00-08:00  241.03  241.03     2
# 2017-11-08 12:52:00-08:00  241.08  241.08     2

# %% [markdown]
# ## Accumulation daily signal
#
# *sum the consecutive accumulation by day*
#
# **Return the 3 biggest daily signals**

# %%
#combine minutes into days
signal = confirmation.resample('D',how='sum')

#sort based on sum(conf)
signal.nlargest(3,'conf')
# Out:
#                            accum  conf
# timestamp
# 2017-11-08 00:00:00-08:00     32    64
# 2017-10-24 00:00:00-07:00     25    50
# 2017-10-03 00:00:00-07:00     23    46

# %% [markdown]
# # Trend
#
# - See if minute bar is making new highs, new lows
# - Return 1 for uptrend or downtrend
# - If new trend starting, flag as buyable or sellable.

# %%
#create trend column based on up or not
ohlc["higher"] = ohlc.high - ohlc.high.shift(1)
ohlc["lower"] = ohlc.low.shift(1) - ohlc.low 


#where >0, give 1
#uptrend means higher highs, downtrend means lower lows, both means expansion, neither means contraction

ohlc["up_tr"] = np.where(ohlc["higher"] > 0, 1, 0)
ohlc["down_tr"] = np.where(ohlc["lower"] > 0, 1, 0)

ohlc["exp"] = np.where((ohlc["higher"]>0) & (ohlc["lower"]>0),1,0)
ohlc["cont"] = np.where((ohlc["higher"]<0) & (ohlc["lower"]<0),1,0)

#where new uptrend established, buyable.. new downtrend sellable
ohlc["buy"] = np.where((ohlc["up_tr"] == 1) & (ohlc["up_tr"].shift(1) == 0), 1, 0)
ohlc["sell"] = np.where((ohlc["down_tr"] == 1) & (ohlc["down_tr"].shift(1) == 0), 1, 0)


#ohlc.tail(3)
ohlc[["high", "low", "close", "higher", "lower", "up_tr", "down_tr", "exp", "cont", "buy", "sell"]].tail(10)
# Out:
#                              high      low    close higher  lower  up_tr  \
# timestamp
# 2017-11-08 12:51:00-08:00  240.85   240.64   240.85  -0.24  -0.03      0
# 2017-11-08 12:52:00-08:00  241.08   240.77   241.08   0.23  -0.13      1
# 2017-11-08 12:53:00-08:00  241.16   241.02  241.105   0.08  -0.25      1
# 2017-11-08 12:54:00-08:00  241.15   241.05   241.09  -0.01  -0.03      0
# 2017-11-08 12:55:00-08:00  241.13   240.98   241.06  -0.02   0.07      0
# 2017-11-08 12:56:00-08:00  241.12   240.89  241.095  -0.01   0.09      0
# 2017-11-08 12:57:00-08:00   241.2      241   241.12   0.08  -0.11      1
# 2017-11-08 12:58:00-08:00  241.25  241.065  241.195   0.05 -0.065      1
# 2017-11-08 12:59:00-08:00   241.3   241.02   241.17   0.05  0.045      1
# 2017-11-08 13:00:00-08:00  241.18   241.18   241.18  -0.12  -0.16      0
#
#                            down_tr  exp  cont  buy  sell
# timestamp
# 2017-11-08 12:51:00-08:00        0    0     1    0     0
# 2017-11-08 12:52:00-08:00        0    0     0    1     0
# 2017-11-08 12:53:00-08:00        0    0     0    0     0
# 2017-11-08 12:54:00-08:00        0    0     1    0     0
# 2017-11-08 12:55:00-08:00        1    0     0    0     1
# 2017-11-08 12:56:00-08:00        1    0     0    0     0
# 2017-11-08 12:57:00-08:00        0    0     0    1     0
# 2017-11-08 12:58:00-08:00        0    0     0    0     0
# 2017-11-08 12:59:00-08:00        1    1     0    0     1
# 2017-11-08 13:00:00-08:00        0    0     1    0     0

# %% [markdown]
# ## Simulation
#
# - Loop through the minute bars, print buys and sells.
# 1 share long on long signal, and 1 share short on short signal.
# This is not additive.  If there's a short on, and a long signal is received, you fully close the short and open the long.

# %%
# PRINTING

total = 0
buys = 0
sells = 0
prev = 0
trade = 0

for index, row in ohlc.iterrows():
    #every row list # buys and sells
    #print buys," long","and",sells,"short"

    if row['buy'] > 0 and buys == 0:
        buys = 1
        sells = 0
        if prev > 0: total = total - row['close'] + prev
            
        print trade,"long from",row['close'],"... total=",total
        
        prev = row['close']
        trade = trade + 1

    if row['sell'] == 1 and sells == 0:
        sells = 1
        buys = 0
        if prev > 0: total = total + row['close'] - prev
            
        print trade,"short from",row['close'],"... total=",total

        prev = row['close']
        trade = trade + 1
# Out:
# 0 short from 248.7 ... total= 0
# 1 long from 249.2392 ... total= -0.5392
# 2 short from 249.07 ... total= -0.7084
# 3 long from 249.0001 ... total= -0.6385
# 4 short from 248.9 ... total= -0.7386
# 5 long from 248.43 ... total= -0.2686
# 6 short from 248.1 ... total= -0.5986
# 7 long from 247.49 ... total= 0.0113999999999
# 8 short from 248.745 ... total= 1.2664
# 9 long from 248.91 ... total= 1.1014
# 10 short from 249.36 ... total= 1.5514
# 11 long from 249.295 ... total= 1.6164
# 12 short from 249.57 ... total= 1.8914
# 13 long from 249.69 ... total= 1.7714
# 14 short from 249.9715 ... total= 2.0529
# 15 long from 250.18 ... total= 1.8444
# 16 short from 249.98 ... total= 1.6444
# 17 long from 250.06 ... total= 1.5644
# 18 short from 250.28 ... total= 1.7844
# 19 long from 250.285 ... total= 1.7794
# 20 short from 250.05 ... total= 1.5444
# 21 long from 250.315 ... total= 1.2794
# 22 short from 249.92 ... total= 0.8844
# 23 long from 249.99 ... total= 0.8144
# 24 short from 249.92 ... total= 0.7444
# 25 long from 249.78 ... total= 0.8844
# 26 short from 249.78 ... total= 0.8844
# 27 long from 249.58 ... total= 1.0844
# 28 short from 249.62 ... total= 1.1244
# 29 long from 249.7228 ... total= 1.0216
# 30 short from 249.615 ... total= 0.9138
# 31 long from 249.69 ... total= 0.8388
# 32 short from 249.62 ... total= 0.7688
# 33 long from 249.27 ... total= 1.1188
# 34 short from 249.11 ... total= 0.9588
# 35 long from 249.095 ... total= 0.9738
# 36 short from 248.92 ... total= 0.7988
# 37 long from 249.22 ... total= 0.4988
# 38 short from 249.26 ... total= 0.5388
# 39 long from 249.16 ... total= 0.6388
# 40 short from 248.89 ... total= 0.3688
# 41 long from 248.91 ... total= 0.3488
# 42 short from 248.68 ... total= 0.1188
# 43 long from 247.81 ... total= 0.9888
# 44 short from 248.06 ... total= 1.2388
# 45 long from 248.17 ... total= 1.1288
# 46 short from 248.13 ... total= 1.0888
# 47 long from 247.84 ... total= 1.3788
# 48 short from 247.515 ... total= 1.0538
# 49 long from 247.3687 ... total= 1.2001
# 50 short from 247.725 ... total= 1.5564
# 51 long from 247.045 ... total= 2.2364
# 52 short from 247.265 ... total= 2.4564
# 53 long from 247.3 ... total= 2.4214
# 54 short from 247.3222 ... total= 2.4436
# 55 long from 248.255 ... total= 1.5108
# 56 short from 248.19 ... total= 1.4458
# 57 long from 248.39 ... total= 1.2458
# 58 short from 248.49 ... total= 1.3458
# 59 long from 248.73 ... total= 1.1058
# 60 short from 248.5371 ... total= 0.9129
# 61 long from 248.4873 ... total= 0.9627
# 62 short from 248.73 ... total= 1.2054
# 63 long from 248.51 ... total= 1.4254
# 64 short from 248.5 ... total= 1.4154
# 65 long from 248.4681 ... total= 1.4473
# 66 short from 248.6029 ... total= 1.5821
# 67 long from 248.4996 ... total= 1.6854
# 68 short from 248.725 ... total= 1.9108
# 69 long from 248.78 ... total= 1.8558
# 70 short from 248.73 ... total= 1.8058
# 71 long from 248.77 ... total= 1.7658
# 72 short from 248.63 ... total= 1.6258
# 73 long from 248.63 ... total= 1.6258
# 74 short from 248.39 ... total= 1.3858
# 75 long from 248.42 ... total= 1.3558
# 76 short from 248.42 ... total= 1.3558
# 77 long from 248.5 ... total= 1.2758
# 78 short from 248.45 ... total= 1.2258
# 79 long from 248.62 ... total= 1.0558
# 80 short from 248.75 ... total= 1.1858
# 81 long from 248.6524 ... total= 1.2834
# 82 short from 248.46 ... total= 1.091
# 83 long from 248.4588 ... total= 1.0922
# 84 short from 248.7349 ... total= 1.3683
# 85 long from 248.8126 ... total= 1.2906
# 86 short from 248.6289 ... total= 1.1069
# 87 long from 248.645 ... total= 1.0908
# 88 short from 248.45 ... total= 0.8958
# 89 long from 248.28 ... total= 1.0658
# 90 short from 248.65 ... total= 1.4358
# 91 long from 248.66 ... total= 1.4258
# 92 short from 248.585 ... total= 1.3508
# 93 long from 248.6564 ... total= 1.2794
# 94 short from 248.595 ... total= 1.218
# 95 long from 248.685 ... total= 1.128
# 96 short from 248.7 ... total= 1.143
# 97 long from 248.619 ... total= 1.224
# 98 short from 248.46 ... total= 1.065
# 99 long from 248.47 ... total= 1.055
# 100 short from 248.31 ... total= 0.895
# 101 long from 248.36 ... total= 0.845
# 102 short from 248.36 ... total= 0.845
# 103 long from 248.1759 ... total= 1.0291
# 104 short from 247.91 ... total= 0.7632
# 105 long from 247.86 ... total= 0.8132
# 106 short from 247.9 ... total= 0.8532
# 107 long from 247.97 ... total= 0.7832
# 108 short from 248.51 ... total= 1.3232
# 109 long from 248.535 ... total= 1.2982
# 110 short from 248.535 ... total= 1.2982
# 111 long from 248.51 ... total= 1.3232
# 112 short from 248.535 ... total= 1.3482
# 113 long from 248.46 ... total= 1.4232
# 114 short from 248.35 ... total= 1.3132
# 115 long from 248.13 ... total= 1.5332
# 116 short from 248.14 ... total= 1.5432
# 117 long from 248.55 ... total= 1.1332
# 118 short from 248.505 ... total= 1.0882
# 119 long from 248.47 ... total= 1.1232
# 120 short from 248.27 ... total= 0.9232
# 121 long from 248.5 ... total= 0.6932
# 122 short from 248.5 ... total= 0.6932
# 123 long from 248.55 ... total= 0.6432
# 124 short from 248.53 ... total= 0.6232
# 125 long from 248.69 ... total= 0.4632
# 126 short from 248.605 ... total= 0.3782
# 127 long from 248.44 ... total= 0.5432
# 128 short from 248.67 ... total= 0.7732
# 129 long from 248.82 ... total= 0.6232
# 130 short from 248.77 ... total= 0.5732
# 131 long from 248.835 ... total= 0.5082
# 132 short from 248.76 ... total= 0.4332
# 133 long from 248.66 ... total= 0.5332
# 134 short from 248.66 ... total= 0.5332
# 135 long from 248.75 ... total= 0.4432
# 136 short from 248.81 ... total= 0.5032
# 137 long from 248.8 ... total= 0.5132
# 138 short from 248.79 ... total= 0.5032
# 139 long from 248.79 ... total= 0.5032
# 140 short from 248.69 ... total= 0.4032
# 141 long from 248.7 ... total= 0.3932
# 142 short from 248.68 ... total= 0.3732
# 143 long from 248.7453 ... total= 0.3079
# 144 short from 248.59 ... total= 0.1526
# 145 long from 248.64 ... total= 0.1026
# 146 short from 248.52 ... total= -0.0174000000003
# 147 long from 248.66 ... total= -0.1574
# 148 short from 248.4 ... total= -0.4174
# 149 long from 248.72 ... total= -0.7374
# 150 short from 248.7 ... total= -0.7574
# 151 long from 249.22 ... total= -1.2774
# 152 short from 249.6 ... total= -0.8974
# 153 long from 249.31 ... total= -0.6074
# 154 short from 249.12 ... total= -0.7974
# 155 long from 249.05 ... total= -0.7274
# 156 short from 249.0 ... total= -0.7774
# 157 long from 248.51 ... total= -0.2874
# 158 short from 249.64 ... total= 0.8426
# 159 long from 249.645 ... total= 0.8376
# 160 short from 249.45 ... total= 0.6426
# 161 long from 248.61 ... total= 1.4826
# 162 short from 248.49 ... total= 1.3626
# 163 long from 248.4331 ... total= 1.4195
# 164 short from 248.4331 ... total= 1.4195
# 165 long from 248.37 ... total= 1.4826
# 166 short from 248.16 ... total= 1.2726
# 167 long from 247.577 ... total= 1.8556
# 168 short from 247.95 ... total= 2.2286
# 169 long from 248.095 ... total= 2.0836
# 170 short from 248.1 ... total= 2.0886
# 171 long from 248.0 ... total= 2.1886
# 172 short from 247.83 ... total= 2.0186
# 173 long from 248.015 ... total= 1.8336
# 174 short from 248.015 ... total= 1.8336
# 175 long from 248.175 ... total= 1.6736
# 176 short from 248.105 ... total= 1.6036
# 177 long from 248.275 ... total= 1.4336
# 178 short from 249.22 ... total= 2.3786
# 179 long from 248.7 ... total= 2.8986
# 180 short from 248.4708 ... total= 2.6694
# 181 long from 248.505 ... total= 2.6352
# 182 short from 248.77 ... total= 2.9002
# 183 long from 248.8876 ... total= 2.7826
# 184 short from 248.9699 ... total= 2.8649
# 185 long from 249.0 ... total= 2.8348
# 186 short from 249.12 ... total= 2.9548
# 187 long from 249.25 ... total= 2.8248
# 188 short from 249.16 ... total= 2.7348
# 189 long from 248.87 ... total= 3.0248
# 190 short from 249.055 ... total= 3.2098
# 191 long from 249.2899 ... total= 2.9749
# 192 short from 249.18 ... total= 2.865
# 193 long from 249.1794 ... total= 2.8656
# 194 short from 249.11 ... total= 2.7962
# 195 long from 248.966 ... total= 2.9402
# 196 short from 248.966 ... total= 2.9402
# 197 long from 249.12 ... total= 2.7862
# 198 short from 249.1203 ... total= 2.7865
# 199 long from 249.22 ... total= 2.6868
# 200 short from 249.2 ... total= 2.6668
# 201 long from 249.015 ... total= 2.8518
# 202 short from 249.015 ... total= 2.8518
# 203 long from 249.22 ... total= 2.6468
# 204 short from 249.15 ... total= 2.5768
# 205 long from 249.04 ... total= 2.6868
# 206 short from 249.04 ... total= 2.6868
# 207 long from 249.03 ... total= 2.6968
# 208 short from 249.03 ... total= 2.6968
# 209 long from 248.92 ... total= 2.8068
# 210 short from 248.92 ... total= 2.8068
# 211 long from 248.88 ... total= 2.8468
# 212 short from 248.96 ... total= 2.9268
# 213 long from 248.8588 ... total= 3.028
# 214 short from 248.8323 ... total= 3.0015
# 215 long from 248.84 ... total= 2.9938
# 216 short from 249.0 ... total= 3.1538
# 217 long from 249.05 ... total= 3.1038
# 218 short from 248.96 ... total= 3.0138
# 219 long from 248.9984 ... total= 2.9754
# 220 short from 248.9 ... total= 2.877
# 221 long from 249.05 ... total= 2.727
# 222 short from 249.0 ... total= 2.677
# 223 long from 249.02 ... total= 2.657
# 224 short from 249.02 ... total= 2.657
# 225 long from 249.09 ... total= 2.587
# 226 short from 249.09 ... total= 2.587
# 227 long from 249.05 ... total= 2.627
# 228 short from 249.021 ... total= 2.598
# 229 long from 249.05 ... total= 2.569
# 230 short from 249.08 ... total= 2.599
# 231 long from 249.06 ... total= 2.619
# 232 short from 249.02 ... total= 2.579
# 233 long from 249.0 ... total= 2.599
# 234 short from 248.655 ... total= 2.254
# 235 long from 248.77 ... total= 2.139
# 236 short from 248.66 ... total= 2.029
# 237 long from 248.7536 ... total= 1.9354
# 238 short from 248.88 ... total= 2.0618
# 239 long from 249.0 ... total= 1.9418
# 240 short from 248.99 ... total= 1.9318
# 241 long from 248.79 ... total= 2.1318
# 242 short from 248.5 ... total= 1.8418
# 243 long from 248.47 ... total= 1.8718
# 244 short from 248.3573 ... total= 1.7591
# 245 long from 248.43 ... total= 1.6864
# 246 short from 248.3095 ... total= 1.5659
# 247 long from 248.31 ... total= 1.5654
# 248 short from 248.465 ... total= 1.7204
# 249 long from 248.5058 ... total= 1.6796
# 250 short from 248.38 ... total= 1.5538
# 251 long from 248.27 ... total= 1.6638
# 252 short from 248.288 ... total= 1.6818
# 253 long from 248.305 ... total= 1.6648
# 254 short from 248.305 ... total= 1.6648
# 255 long from 248.26 ... total= 1.7098
# 256 short from 248.26 ... total= 1.7098
# 257 long from 248.29 ... total= 1.6798
# 258 short from 248.21 ... total= 1.5998
# 259 long from 248.239 ... total= 1.5708
# 260 short from 248.11 ... total= 1.4418
# 261 long from 248.14 ... total= 1.4118
# 262 short from 248.0976 ... total= 1.3694
# 263 long from 248.08 ... total= 1.387
# 264 short from 248.14 ... total= 1.447
# 265 long from 248.1333 ... total= 1.4537
# 266 short from 247.55 ... total= 0.8704
# 267 long from 247.4083 ... total= 1.0121
# 268 short from 247.42 ... total= 1.0238
# 269 long from 247.38 ... total= 1.0638
# 270 short from 247.47 ... total= 1.1538
# 271 long from 247.48 ... total= 1.1438
# 272 short from 247.4792 ... total= 1.143
# 273 long from 247.61 ... total= 1.0122
# 274 short from 247.33 ... total= 0.7322
# 275 long from 247.56 ... total= 0.5022
# 276 short from 247.39 ... total= 0.3322
# 277 long from 247.45 ... total= 0.2722
# 278 short from 247.76 ... total= 0.5822
# 279 long from 247.68 ... total= 0.6622
# 280 short from 247.68 ... total= 0.6622
# 281 long from 247.64 ... total= 0.7022
# 282 short from 247.52 ... total= 0.5822
# 283 long from 247.49 ... total= 0.6122
# 284 short from 247.49 ... total= 0.6122
# 285 long from 247.53 ... total= 0.5722
# 286 short from 247.55 ... total= 0.5922
# 287 long from 247.14 ... total= 1.0022
# 288 short from 247.01 ... total= 0.8722
# 289 long from 247.09 ... total= 0.7922
# 290 short from 247.06 ... total= 0.7622
# 291 long from 247.0446 ... total= 0.7776
# 292 short from 247.01 ... total= 0.743
# 293 long from 247.01 ... total= 0.743
# 294 short from 246.93 ... total= 0.663
# 295 long from 246.68 ... total= 0.913
# 296 short from 246.72 ... total= 0.953
# 297 long from 246.83 ... total= 0.843
# 298 short from 247.18 ... total= 1.193
# 299 long from 247.005 ... total= 1.368
# 300 short from 246.95 ... total= 1.313
# 301 long from 247.25 ... total= 1.013
# 302 short from 247.21 ... total= 0.973
# 303 long from 247.16 ... total= 1.023
# 304 short from 246.98 ... total= 0.843
# 305 long from 246.98 ... total= 0.843
# 306 short from 246.58 ... total= 0.443
# 307 long from 246.77 ... total= 0.253
# 308 short from 246.66 ... total= 0.143
# 309 long from 246.35 ... total= 0.453
# 310 short from 246.36 ... total= 0.463
# 311 long from 246.4 ... total= 0.423
# 312 short from 246.28 ... total= 0.303
# 313 long from 245.66 ... total= 0.923
# 314 short from 245.77 ... total= 1.033
# 315 long from 245.665 ... total= 1.138
# 316 short from 246.02 ... total= 1.493
# 317 long from 246.38 ... total= 1.133
# 318 short from 246.31 ... total= 1.063
# 319 long from 246.4899 ... total= 0.8831
# 320 short from 246.44 ... total= 0.8332
# 321 long from 246.165 ... total= 1.1082
# 322 short from 246.18 ... total= 1.1232
# 323 long from 245.025 ... total= 2.2782
# 324 short from 245.025 ... total= 2.2782
# 325 long from 245.14 ... total= 2.1632
# 326 short from 245.14 ... total= 2.1632
# 327 long from 245.15 ... total= 2.1532
# 328 short from 245.15 ... total= 2.1532
# 329 long from 245.27 ... total= 2.0332
# 330 short from 245.006 ... total= 1.7692
# 331 long from 245.56 ... total= 1.2152
# 332 short from 245.2 ... total= 0.8552
# 333 long from 244.98 ... total= 1.0752
# 334 short from 244.7887 ... total= 0.8839
# 335 long from 244.995 ... total= 0.6776
# 336 short from 245.97 ... total= 1.6526
# 337 long from 246.005 ... total= 1.6176
# 338 short from 245.97 ... total= 1.5826
# 339 long from 246.13 ... total= 1.4226
# 340 short from 246.025 ... total= 1.3176
# 341 long from 246.01 ... total= 1.3326
# 342 short from 245.9411 ... total= 1.2637
# 343 long from 245.95 ... total= 1.2548
# 344 short from 245.9 ... total= 1.2048
# 345 long from 246.05 ... total= 1.0548
# 346 short from 246.0663 ... total= 1.0711
# 347 long from 246.21 ... total= 0.9274
# 348 short from 246.015 ... total= 0.7324
# 349 long from 246.27 ... total= 0.4774
# 350 short from 246.19 ... total= 0.3974
# 351 long from 246.27 ... total= 0.3174
# 352 short from 246.1624 ... total= 0.2098
# 353 long from 246.345 ... total= 0.0271999999997
# 354 short from 246.32 ... total= 0.00219999999973
# 355 long from 246.3 ... total= 0.0221999999997
# 356 short from 246.3 ... total= 0.0221999999997
# 357 long from 246.1201 ... total= 0.2021
# 358 short from 246.3485 ... total= 0.4305
# 359 long from 246.28 ... total= 0.499
# 360 short from 246.28 ... total= 0.499
# 361 long from 246.33 ... total= 0.449
# 362 short from 246.4 ... total= 0.519
# 363 long from 246.3432 ... total= 0.5758
# 364 short from 246.02 ... total= 0.2526
# 365 long from 245.89 ... total= 0.3826
# 366 short from 246.0 ... total= 0.4926
# 367 long from 246.1 ... total= 0.3926
# 368 short from 246.12 ... total= 0.4126
# 369 long from 246.08 ... total= 0.4526
# 370 short from 246.275 ... total= 0.6476
# 371 long from 246.2 ... total= 0.7226
# 372 short from 246.25 ... total= 0.7726
# 373 long from 246.205 ... total= 0.8176
# 374 short from 246.09 ... total= 0.7026
# 375 long from 246.09 ... total= 0.7026
# 376 short from 246.31 ... total= 0.9226
# 377 long from 246.41 ... total= 0.8226
# 378 short from 246.41 ... total= 0.8226
# 379 long from 246.27 ... total= 0.9626
# 380 short from 246.18 ... total= 0.8726
# 381 long from 246.17 ... total= 0.8826
# 382 short from 246.17 ... total= 0.8826
# 383 long from 246.15 ... total= 0.9026
# 384 short from 246.21 ... total= 0.9626
# 385 long from 246.165 ... total= 1.0076
# 386 short from 246.07 ... total= 0.9126
# 387 long from 245.98 ... total= 1.0026
# 388 short from 245.92 ... total= 0.9426
# 389 long from 245.9926 ... total= 0.87
# 390 short from 245.81 ... total= 0.6874
# 391 long from 245.9 ... total= 0.5974
# 392 short from 246.17 ... total= 0.8674
# 393 long from 246.02 ... total= 1.0174
# 394 short from 245.96 ... total= 0.9574
# 395 long from 245.75 ... total= 1.1674
# 396 short from 245.62 ... total= 1.0374
# 397 long from 245.75 ... total= 0.9074
# 398 short from 245.75 ... total= 0.9074
# 399 long from 245.72 ... total= 0.9374
# 400 short from 245.6418 ... total= 0.8592
# 401 long from 245.4 ... total= 1.101
# 402 short from 245.4 ... total= 1.101
# 403 long from 245.47 ... total= 1.031
# 404 short from 245.53 ... total= 1.091
# 405 long from 244.21 ... total= 2.411
# 406 short from 244.35 ... total= 2.551
# 407 long from 244.4 ... total= 2.501
# 408 short from 244.3076 ... total= 2.4086
# 409 long from 244.39 ... total= 2.3262
# 410 short from 244.49 ... total= 2.4262
# 411 long from 244.8489 ... total= 2.0673
# 412 short from 244.775 ... total= 1.9934
# 413 long from 244.68 ... total= 2.0884
# 414 short from 244.48 ... total= 1.8884
# 415 long from 244.48 ... total= 1.8884
# 416 short from 244.53 ... total= 1.9384
# 417 long from 244.3687 ... total= 2.0997
# 418 short from 244.185 ... total= 1.916
# 419 long from 244.1774 ... total= 1.9236
# 420 short from 244.1 ... total= 1.8462
# 421 long from 244.0 ... total= 1.9462
# 422 short from 244.05 ... total= 1.9962
# 423 long from 244.1 ... total= 1.9462
# 424 short from 244.21 ... total= 2.0562
# 425 long from 243.924 ... total= 2.3422
# 426 short from 244.02 ... total= 2.4382
# 427 long from 244.0535 ... total= 2.4047
# 428 short from 244.1 ... total= 2.4512
# 429 long from 244.0725 ... total= 2.4787
# 430 short from 244.03 ... total= 2.4362
# 431 long from 244.1525 ... total= 2.3137
# 432 short from 244.0272 ... total= 2.1884
# 433 long from 243.8601 ... total= 2.3555
# 434 short from 243.8601 ... total= 2.3555
# 435 long from 243.885 ... total= 2.3306
# 436 short from 243.93 ... total= 2.3756
# 437 long from 243.8812 ... total= 2.4244
# 438 short from 243.9 ... total= 2.4432
# 439 long from 243.945 ... total= 2.3982
# 440 short from 243.93 ... total= 2.3832
# 441 long from 244.08 ... total= 2.2332
# 442 short from 244.08 ... total= 2.2332
# 443 long from 244.18 ... total= 2.1332
# 444 short from 244.18 ... total= 2.1332
# 445 long from 243.95 ... total= 2.3632
# 446 short from 244.0 ... total= 2.4132
# 447 long from 243.96 ... total= 2.4532
# 448 short from 243.87 ... total= 2.3632
# 449 long from 243.96 ... total= 2.2732
# 450 short from 243.91 ... total= 2.2232
# 451 long from 244.095 ... total= 2.0382
# 452 short from 243.895 ... total= 1.8382
# 453 long from 243.98 ... total= 1.7532
# 454 short from 243.98 ... total= 1.7532
# 455 long from 244.09 ... total= 1.6432
# 456 short from 244.08 ... total= 1.6332
# 457 long from 244.46 ... total= 1.2532
# 458 short from 244.37 ... total= 1.1632
# 459 long from 244.4 ... total= 1.1332
# 460 short from 244.41 ... total= 1.1432
# 461 long from 246.155 ... total= -0.6018
# 462 short from 247.095 ... total= 0.3382
# 463 long from 246.99 ... total= 0.4432
# 464 short from 246.42 ... total= -0.1268
# 465 long from 246.44 ... total= -0.1468
# 466 short from 246.44 ... total= -0.1468
# 467 long from 246.87 ... total= -0.5768
# 468 short from 246.87 ... total= -0.5768
# 469 long from 246.79 ... total= -0.4968
# 470 short from 246.72 ... total= -0.5668
# 471 long from 246.83 ... total= -0.6768
# 472 short from 247.13 ... total= -0.3768
# 473 long from 246.8 ... total= -0.0468000000002
# 474 short from 246.8 ... total= -0.0468000000002
# 475 long from 246.48 ... total= 0.2732
# 476 short from 246.17 ... total= -0.0368000000002
# 477 long from 246.0 ... total= 0.1332
# 478 short from 246.02 ... total= 0.1532
# 479 long from 245.52 ... total= 0.6532
# 480 short from 245.36 ... total= 0.4932
# 481 long from 245.19 ... total= 0.6632
# 482 short from 245.19 ... total= 0.6632
# 483 long from 244.87 ... total= 0.9832
# 484 short from 244.76 ... total= 0.8732
# 485 long from 244.75 ... total= 0.8832
# 486 short from 244.75 ... total= 0.8832
# 487 long from 244.765 ... total= 0.8682
# 488 short from 244.63 ... total= 0.7332
# 489 long from 243.15 ... total= 2.2132
# 490 short from 242.22 ... total= 1.2832
# 491 long from 242.845 ... total= 0.6582
# 492 short from 242.845 ... total= 0.6582
# 493 long from 244.16 ... total= -0.6568
# 494 short from 244.0 ... total= -0.8168
# 495 long from 243.66 ... total= -0.4768
# 496 short from 243.73 ... total= -0.4068
# 497 long from 244.125 ... total= -0.8018
# 498 short from 244.08 ... total= -0.8468
# 499 long from 243.895 ... total= -0.6618
# 500 short from 244.0 ... total= -0.5568
# 501 long from 243.8 ... total= -0.3568
# 502 short from 243.69 ... total= -0.4668
# 503 long from 243.64 ... total= -0.4168
# 504 short from 243.8 ... total= -0.2568
# 505 long from 243.6 ... total= -0.0568000000002
# 506 short from 243.6 ... total= -0.0568000000002
# 507 long from 243.8098 ... total= -0.2666
# 508 short from 244.69 ... total= 0.6136
# 509 long from 244.84 ... total= 0.4636
# 510 short from 244.8702 ... total= 0.4938
# 511 long from 244.88 ... total= 0.484
# 512 short from 244.9137 ... total= 0.5177
# 513 long from 244.97 ... total= 0.4614
# 514 short from 244.96 ... total= 0.4514
# 515 long from 244.75 ... total= 0.6614
# 516 short from 244.55 ... total= 0.4614
# 517 long from 244.39 ... total= 0.6214
# 518 short from 244.28 ... total= 0.5114
# 519 long from 244.37 ... total= 0.4214
# 520 short from 244.2 ... total= 0.2514
# 521 long from 244.31 ... total= 0.1414
# 522 short from 244.26 ... total= 0.0913999999999
# 523 long from 244.26 ... total= 0.0913999999999
# 524 short from 244.38 ... total= 0.2114
# 525 long from 244.33 ... total= 0.2614
# 526 short from 244.33 ... total= 0.2614
# 527 long from 244.09 ... total= 0.5014
# 528 short from 244.02 ... total= 0.4314
# 529 long from 244.03 ... total= 0.4214
# 530 short from 244.3 ... total= 0.6914
# 531 long from 244.2808 ... total= 0.7106
# 532 short from 244.53 ... total= 0.9598
# 533 long from 244.41 ... total= 1.0798
# 534 short from 244.42 ... total= 1.0898
# 535 long from 244.4 ... total= 1.1098
# 536 short from 244.46 ... total= 1.1698
# 537 long from 244.5 ... total= 1.1298
# 538 short from 244.42 ... total= 1.0498
# 539 long from 244.5 ... total= 0.9698
# 540 short from 244.42 ... total= 0.8898
# 541 long from 244.33 ... total= 0.9798
# 542 short from 244.275 ... total= 0.9248
# 543 long from 244.025 ... total= 1.1748
# 544 short from 244.1422 ... total= 1.292
# 545 long from 244.44 ... total= 0.9942
# 546 short from 244.18 ... total= 0.7342
# 547 long from 244.285 ... total= 0.6292
# 548 short from 244.34 ... total= 0.6842
# 549 long from 244.35 ... total= 0.6742
# 550 short from 244.3829 ... total= 0.7071
# 551 long from 244.3 ... total= 0.79
# 552 short from 244.22 ... total= 0.71
# 553 long from 244.4373 ... total= 0.4927
# 554 short from 244.21 ... total= 0.2654
# 555 long from 244.25 ... total= 0.2254
# 556 short from 244.284 ... total= 0.2594
# 557 long from 244.12 ... total= 0.4234
# 558 short from 244.12 ... total= 0.4234
# 559 long from 243.9026 ... total= 0.6408
# 560 short from 243.9026 ... total= 0.6408
# 561 long from 243.8736 ... total= 0.6698
# 562 short from 243.68 ... total= 0.4762
# 563 long from 243.78 ... total= 0.3762
# 564 short from 243.7304 ... total= 0.3266
# 565 long from 243.7 ... total= 0.357
# 566 short from 244.12 ... total= 0.777
# 567 long from 244.05 ... total= 0.847
# 568 short from 243.955 ... total= 0.752
# 569 long from 244.0 ... total= 0.707
# 570 short from 244.16 ... total= 0.867
# 571 long from 244.15 ... total= 0.877
# 572 short from 244.0495 ... total= 0.7765
# 573 long from 244.11 ... total= 0.716
# 574 short from 244.07 ... total= 0.676
# 575 long from 244.15 ... total= 0.596
# 576 short from 243.9 ... total= 0.346
# 577 long from 243.9598 ... total= 0.2862
# 578 short from 243.9 ... total= 0.2264
# 579 long from 243.99 ... total= 0.1364
# 580 short from 243.96 ... total= 0.1064
# 581 long from 244.01 ... total= 0.0563999999999
# 582 short from 243.98 ... total= 0.0263999999999
# 583 long from 244.0 ... total= 0.00639999999987
# 584 short from 244.18 ... total= 0.1864
# 585 long from 244.07 ... total= 0.2964
# 586 short from 244.07 ... total= 0.2964
# 587 long from 244.35 ... total= 0.0163999999999
# 588 short from 244.54 ... total= 0.2064
# 589 long from 244.59 ... total= 0.1564
# 590 short from 244.5 ... total= 0.0663999999999
# 591 long from 244.6 ... total= -0.0336000000001
# 592 short from 244.52 ... total= -0.1136
# 593 long from 244.57 ... total= -0.1636
# 594 short from 244.5502 ... total= -0.1834
# 595 long from 244.65 ... total= -0.2832
# 596 short from 244.53 ... total= -0.4032
# 597 long from 244.69 ... total= -0.5632
# 598 short from 245.27 ... total= 0.0167999999999
# 599 long from 245.25 ... total= 0.0367999999999
# 600 short from 245.31 ... total= 0.0967999999999
# 601 long from 245.38 ... total= 0.0267999999999
# 602 short from 245.4 ... total= 0.0467999999999
# 603 long from 245.34 ... total= 0.1068
# 604 short from 245.34 ... total= 0.1068
# 605 long from 245.39 ... total= 0.0568
# 606 short from 245.33 ... total= -0.00320000000002
# 607 long from 245.3216 ... total= 0.0052
# 608 short from 245.26 ... total= -0.0564
# 609 long from 245.32 ... total= -0.1164
# 610 short from 245.56 ... total= 0.1236
# 611 long from 245.035 ... total= 0.6486
# 612 short from 245.17 ... total= 0.7836
# 613 long from 244.81 ... total= 1.1436
# 614 short from 244.81 ... total= 1.1436
# 615 long from 245.76 ... total= 0.1936
# 616 short from 244.89 ... total= -0.6764
# 617 long from 245.28 ... total= -1.0664
# 618 short from 245.1 ... total= -1.2464
# 619 long from 245.3984 ... total= -1.5448
# 620 short from 245.685 ... total= -1.2582
# 621 long from 245.72 ... total= -1.2932
# 622 short from 245.72 ... total= -1.2932
# 623 long from 245.14 ... total= -0.7132
# 624 short from 245.88 ... total= 0.0268
# 625 long from 245.959 ... total= -0.0522
# 626 short from 245.58 ... total= -0.4312
# 627 long from 245.69 ... total= -0.5412
# 628 short from 245.395 ... total= -0.8362
# 629 long from 245.9799 ... total= -1.4211
# 630 short from 245.76 ... total= -1.641
# 631 long from 245.64 ... total= -1.521
# 632 short from 245.625 ... total= -1.536
# 633 long from 245.9 ... total= -1.811
# 634 short from 245.7948 ... total= -1.9162
# 635 long from 245.765 ... total= -1.8864
# 636 short from 245.765 ... total= -1.8864
# 637 long from 245.69 ... total= -1.8114
# 638 short from 245.84 ... total= -1.6614
# 639 long from 245.7226 ... total= -1.544
# 640 short from 245.4857 ... total= -1.7809
# 641 long from 245.5 ... total= -1.7952
# 642 short from 245.4 ... total= -1.8952
# 643 long from 245.1716 ... total= -1.6668
# 644 short from 245.1716 ... total= -1.6668
# 645 long from 245.0 ... total= -1.4952
# 646 short from 245.0 ... total= -1.4952
# 647 long from 245.03 ... total= -1.5252
# 648 short from 244.96 ... total= -1.5952
# 649 long from 245.005 ... total= -1.6402
# 650 short from 245.29 ... total= -1.3552
# 651 long from 245.145 ... total= -1.2102
# 652 short from 244.71 ... total= -1.6452
# 653 long from 244.8 ... total= -1.7352
# 654 short from 244.874 ... total= -1.6612
# 655 long from 245.05 ... total= -1.8372
# 656 short from 245.05 ... total= -1.8372
# 657 long from 245.035 ... total= -1.8222
# 658 short from 245.14 ... total= -1.7172
# 659 long from 245.1426 ... total= -1.7198
# 660 short from 245.09 ... total= -1.7724
# 661 long from 245.05 ... total= -1.7324
# 662 short from 245.1 ... total= -1.6824
# 663 long from 245.24 ... total= -1.8224
# 664 short from 245.09 ... total= -1.9724
# 665 long from 245.27 ... total= -2.1524
# 666 short from 245.42 ... total= -2.0024
# 667 long from 245.2 ... total= -1.7824
# 668 short from 245.14 ... total= -1.8424
# 669 long from 245.31 ... total= -2.0124
# 670 short from 245.2 ... total= -2.1224
# 671 long from 245.27 ... total= -2.1924
# 672 short from 244.97 ... total= -2.4924
# 673 long from 245.21 ... total= -2.7324
# 674 short from 245.2 ... total= -2.7424
# 675 long from 245.15 ... total= -2.6924
# 676 short from 245.12 ... total= -2.7224
# 677 long from 245.225 ... total= -2.8274
# 678 short from 245.29 ... total= -2.7624
# 679 long from 245.43 ... total= -2.9024
# 680 short from 245.3 ... total= -3.0324
# 681 long from 245.15 ... total= -2.8824
# 682 short from 245.15 ... total= -2.8824
# 683 long from 245.0 ... total= -2.7324
# 684 short from 245.22 ... total= -2.5124
# 685 long from 245.39 ... total= -2.6824
# 686 short from 245.305 ... total= -2.7674
# 687 long from 245.32 ... total= -2.7824
# 688 short from 245.49 ... total= -2.6124
# 689 long from 245.5578 ... total= -2.6802
# 690 short from 245.63 ... total= -2.608
# 691 long from 246.13 ... total= -3.108
# 692 short from 246.08 ... total= -3.158
# 693 long from 245.9549 ... total= -3.0329
# 694 short from 245.98 ... total= -3.0078
# 695 long from 246.03 ... total= -3.0578
# 696 short from 245.98 ... total= -3.1078
# 697 long from 245.88 ... total= -3.0078
# 698 short from 245.88 ... total= -3.0078
# 699 long from 245.96 ... total= -3.0878
# 700 short from 246.05 ... total= -2.9978
# 701 long from 245.89 ... total= -2.8378
# 702 short from 246.02 ... total= -2.7078
# 703 long from 245.85 ... total= -2.5378
# 704 short from 245.85 ... total= -2.5378
# 705 long from 245.84 ... total= -2.5278
# 706 short from 245.9 ... total= -2.4678
# 707 long from 245.98 ... total= -2.5478
# 708 short from 245.74 ... total= -2.7878
# 709 long from 245.85 ... total= -2.8978
# 710 short from 245.81 ... total= -2.9378
# 711 long from 245.85 ... total= -2.9778
# 712 short from 245.85 ... total= -2.9778
# 713 long from 245.865 ... total= -2.9928
# 714 short from 245.76 ... total= -3.0978
# 715 long from 245.7 ... total= -3.0378
# 716 short from 245.79 ... total= -2.9478
# 717 long from 245.82 ... total= -2.9778
# 718 short from 246.01 ... total= -2.7878
# 719 long from 245.89 ... total= -2.6678
# 720 short from 245.905 ... total= -2.6528
# 721 long from 246.0 ... total= -2.7478
# 722 short from 245.88 ... total= -2.8678
# 723 long from 246.4491 ... total= -3.4369
# 724 short from 246.69 ... total= -3.196
# 725 long from 247.13 ... total= -3.636
# 726 short from 246.99 ... total= -3.776
# 727 long from 247.0 ... total= -3.786
# 728 short from 246.87 ... total= -3.916
# 729 long from 246.935 ... total= -3.981
# 730 short from 247.18 ... total= -3.736
# 731 long from 246.89 ... total= -3.446
# 732 short from 246.73 ... total= -3.606
# 733 long from 246.7358 ... total= -3.6118
# 734 short from 246.686 ... total= -3.6616
# 735 long from 246.73 ... total= -3.7056
# 736 short from 246.91 ... total= -3.5256
# 737 long from 246.79 ... total= -3.4056
# 738 short from 246.78 ... total= -3.4156
# 739 long from 246.9 ... total= -3.5356
# 740 short from 246.9 ... total= -3.5356
# 741 long from 247.15 ... total= -3.7856
# 742 short from 247.385 ... total= -3.5506
# 743 long from 247.44 ... total= -3.6056
# 744 short from 247.31 ... total= -3.7356
# 745 long from 247.3378 ... total= -3.7634
# 746 short from 247.2 ... total= -3.9012
# 747 long from 247.25 ... total= -3.9512
# 748 short from 247.13 ... total= -4.0712
# 749 long from 247.09 ... total= -4.0312
# 750 short from 247.08 ... total= -4.0412
# 751 long from 247.08 ... total= -4.0412
# 752 short from 247.094 ... total= -4.0272
# 753 long from 247.22 ... total= -4.1532
# 754 short from 247.26 ... total= -4.1132
# 755 long from 247.24 ... total= -4.0932
# 756 short from 247.5699 ... total= -3.7633
# 757 long from 247.6 ... total= -3.7934
# 758 short from 247.66 ... total= -3.7334
# 759 long from 247.85 ... total= -3.9234
# 760 short from 247.71 ... total= -4.0634
# 761 long from 247.75 ... total= -4.1034
# 762 short from 247.655 ... total= -4.1984
# 763 long from 247.635 ... total= -4.1784
# 764 short from 247.57 ... total= -4.2434
# 765 long from 247.52 ... total= -4.1934
# 766 short from 248.66 ... total= -3.0534
# 767 long from 248.76 ... total= -3.1534
# 768 short from 248.55 ... total= -3.3634
# 769 long from 248.36 ... total= -3.1734
# 770 short from 248.22 ... total= -3.3134
# 771 long from 248.455 ... total= -3.5484
# 772 short from 248.34 ... total= -3.6634
# 773 long from 248.52 ... total= -3.8434
# 774 short from 248.33 ... total= -4.0334
# 775 long from 248.33 ... total= -4.0334
# 776 short from 248.33 ... total= -4.0334
# 777 long from 248.335 ... total= -4.0384
# 778 short from 248.335 ... total= -4.0384
# 779 long from 248.5 ... total= -4.2034
# 780 short from 248.48 ... total= -4.2234
# 781 long from 248.5 ... total= -4.2434
# 782 short from 248.4176 ... total= -4.3258
# 783 long from 248.49 ... total= -4.3982
# 784 short from 248.21 ... total= -4.6782
# 785 long from 248.51 ... total= -4.9782
# 786 short from 248.35 ... total= -5.1382
# 787 long from 248.35 ... total= -5.1382
# 788 short from 248.25 ... total= -5.2382
# 789 long from 248.44 ... total= -5.4282
# 790 short from 248.4318 ... total= -5.4364
# 791 long from 249.46 ... total= -6.4646
# 792 short from 249.61 ... total= -6.3146
# 793 long from 249.63 ... total= -6.3346
# 794 short from 249.51 ... total= -6.4546
# 795 long from 250.28 ... total= -7.2246
# 796 short from 249.22 ... total= -8.2846
# 797 long from 249.13 ... total= -8.1946
# 798 short from 249.1 ... total= -8.2246
# 799 long from 249.11 ... total= -8.2346
# 800 short from 249.52 ... total= -7.8246
# 801 long from 249.38 ... total= -7.6846
# 802 short from 249.41 ... total= -7.6546
# 803 long from 249.45 ... total= -7.6946
# 804 short from 249.4 ... total= -7.7446
# 805 long from 249.5 ... total= -7.8446
# 806 short from 249.41 ... total= -7.9346
# 807 long from 249.5 ... total= -8.0246
# 808 short from 249.28 ... total= -8.2446
# 809 long from 249.35 ... total= -8.3146
# 810 short from 249.49 ... total= -8.1746
# 811 long from 249.499 ... total= -8.1836
# 812 short from 249.5 ... total= -8.1826
# 813 long from 249.45 ... total= -8.1326
# 814 short from 249.44 ... total= -8.1426
# 815 long from 249.45 ... total= -8.1526
# 816 short from 249.49 ... total= -8.1126
# 817 long from 249.45 ... total= -8.0726
# 818 short from 249.431 ... total= -8.0916
# 819 long from 249.36 ... total= -8.0206
# 820 short from 249.24 ... total= -8.1406
# 821 long from 249.21 ... total= -8.1106
# 822 short from 249.21 ... total= -8.1106
# 823 long from 249.44 ... total= -8.3406
# 824 short from 249.4005 ... total= -8.3801
# 825 long from 249.5 ... total= -8.4796
# 826 short from 249.5 ... total= -8.4796
# 827 long from 249.38 ... total= -8.3596
# 828 short from 249.29 ... total= -8.4496
# 829 long from 249.18 ... total= -8.3396
# 830 short from 249.18 ... total= -8.3396
# 831 long from 249.81 ... total= -8.9696
# 832 short from 249.88 ... total= -8.8996
# 833 long from 250.07 ... total= -9.0896
# 834 short from 250.67 ... total= -8.4896
# 835 long from 250.69 ... total= -8.5096
# 836 short from 250.56 ... total= -8.6396
# 837 long from 250.7047 ... total= -8.7843
# 838 short from 250.65 ... total= -8.839
# 839 long from 250.71 ... total= -8.899
# 840 short from 250.65 ... total= -8.959
# 841 long from 250.66 ... total= -8.969
# 842 short from 250.66 ... total= -8.969
# 843 long from 250.75 ... total= -9.059
# 844 short from 251.0272 ... total= -8.7818
# 845 long from 251.2 ... total= -8.9546
# 846 short from 251.01 ... total= -9.1446
# 847 long from 250.94 ... total= -9.0746
# 848 short from 251.2 ... total= -8.8146
# 849 long from 251.27 ... total= -8.8846
# 850 short from 251.2 ... total= -8.9546
# 851 long from 251.27 ... total= -9.0246
# 852 short from 251.22 ... total= -9.0746
# 853 long from 251.17 ... total= -9.0246
# 854 short from 251.17 ... total= -9.0246
# 855 long from 251.2069 ... total= -9.0615
# 856 short from 251.142 ... total= -9.1264
# 857 long from 251.21 ... total= -9.1944
# 858 short from 251.18 ... total= -9.2244
# 859 long from 251.28 ... total= -9.3244
# 860 short from 251.25 ... total= -9.3544
# 861 long from 251.4 ... total= -9.5044
# 862 short from 251.17 ... total= -9.7344
# 863 long from 251.33 ... total= -9.8944
# 864 short from 251.28 ... total= -9.9444
# 865 long from 251.37 ... total= -10.0344
# 866 short from 251.24 ... total= -10.1644
# 867 long from 251.21 ... total= -10.1344
# 868 short from 251.21 ... total= -10.1344
# 869 long from 251.23 ... total= -10.1544
# 870 short from 251.25 ... total= -10.1344
# 871 long from 251.21 ... total= -10.0944
# 872 short from 251.39 ... total= -9.9144
# 873 long from 252.31 ... total= -10.8344
# 874 short from 252.35 ... total= -10.7944
# 875 long from 252.382 ... total= -10.8264
# 876 short from 252.79 ... total= -10.4184
# 877 long from 252.935 ... total= -10.5634
# 878 short from 252.8 ... total= -10.6984
# 879 long from 253.04 ... total= -10.9384
# 880 short from 253.04 ... total= -10.9384
# 881 long from 253.32 ... total= -11.2184
# 882 short from 253.33 ... total= -11.2084
# 883 long from 253.4106 ... total= -11.289
# 884 short from 253.57 ... total= -11.1296
# 885 long from 253.6672 ... total= -11.2268
# 886 short from 253.61 ... total= -11.284
# 887 long from 253.39 ... total= -11.064
# 888 short from 253.45 ... total= -11.004
# 889 long from 253.79 ... total= -11.344
# 890 short from 254.021 ... total= -11.113
# 891 long from 254.0638 ... total= -11.1558
# 892 short from 254.19 ... total= -11.0296
# 893 long from 253.6095 ... total= -10.4491
# 894 short from 253.725 ... total= -10.3336
# 895 long from 253.7504 ... total= -10.359
# 896 short from 253.6073 ... total= -10.5021
# 897 long from 253.7 ... total= -10.5948
# 898 short from 253.6889 ... total= -10.6059
# 899 long from 253.9 ... total= -10.817
# 900 short from 253.92 ... total= -10.797
# 901 long from 254.05 ... total= -10.927
# 902 short from 253.9167 ... total= -11.0603
# 903 long from 253.78 ... total= -10.9236
# 904 short from 253.78 ... total= -10.9236
# 905 long from 253.07 ... total= -10.2136
# 906 short from 252.66 ... total= -10.6236
# 907 long from 252.71 ... total= -10.6736
# 908 short from 252.71 ... total= -10.6736
# 909 long from 253.1 ... total= -11.0636
# 910 short from 253.1 ... total= -11.0636
# 911 long from 253.07 ... total= -11.0336
# 912 short from 253.02 ... total= -11.0836
# 913 long from 253.17 ... total= -11.2336
# 914 short from 252.99 ... total= -11.4136
# 915 long from 253.07 ... total= -11.4936
# 916 short from 252.72 ... total= -11.8436
# 917 long from 252.75 ... total= -11.8736
# 918 short from 252.67 ... total= -11.9536
# 919 long from 252.66 ... total= -11.9436
# 920 short from 252.52 ... total= -12.0836
# 921 long from 252.39 ... total= -11.9536
# 922 short from 252.29 ... total= -12.0536
# 923 long from 252.11 ... total= -11.8736
# 924 short from 253.525 ... total= -10.4586
# 925 long from 254.695 ... total= -11.6286
# 926 short from 254.99 ... total= -11.3336
# 927 long from 254.624 ... total= -10.9676
# 928 short from 257.18 ... total= -8.4116
# 929 long from 257.845 ... total= -9.0766
# 930 short from 257.79 ... total= -9.1316
# 931 long from 257.7166 ... total= -9.0582
# 932 short from 259.4225 ... total= -7.3523
# 933 long from 259.3 ... total= -7.2298
# 934 short from 259.24 ... total= -7.2898
# 935 long from 258.81 ... total= -6.8598
# 936 short from 258.89 ... total= -6.7798
# 937 long from 257.02 ... total= -4.9098
# 938 short from 256.67 ... total= -5.2598
# 939 long from 257.45 ... total= -6.0398
# 940 short from 257.76 ... total= -5.7298
# 941 long from 257.5101 ... total= -5.4799
# 942 short from 257.88 ... total= -5.11
# 943 long from 258.02 ... total= -5.25
# 944 short from 257.77 ... total= -5.5
# 945 long from 257.9999 ... total= -5.7299
# 946 short from 258.1 ... total= -5.6298
# 947 long from 257.86 ... total= -5.3898
# 948 short from 258.075 ... total= -5.1748
# 949 long from 258.12 ... total= -5.2198
# 950 short from 258.13 ... total= -5.2098
# 951 long from 258.14 ... total= -5.2198
# 952 short from 259.1888 ... total= -4.171
# 953 long from 259.7853 ... total= -4.7675
# 954 short from 259.71 ... total= -4.8428
# 955 long from 259.7102 ... total= -4.843
# 956 short from 259.695 ... total= -4.8582
# 957 long from 258.6375 ... total= -3.8007
# 958 short from 259.29 ... total= -3.1482
# 959 long from 259.64 ... total= -3.4982
# 960 short from 260.3364 ... total= -2.8018
# 961 long from 260.22 ... total= -2.6854
# 962 short from 259.98 ... total= -2.9254
# 963 long from 260.0974 ... total= -3.0428
# 964 short from 260.0974 ... total= -3.0428
# 965 long from 260.135 ... total= -3.0804
# 966 short from 260.23 ... total= -2.9854
# 967 long from 260.32 ... total= -3.0754
# 968 short from 260.92 ... total= -2.4754
# 969 long from 261.69 ... total= -3.2454
# 970 short from 261.1843 ... total= -3.7511
# 971 long from 260.44 ... total= -3.0068
# 972 short from 260.0 ... total= -3.4468
# 973 long from 259.735 ... total= -3.1818
# 974 short from 259.66 ... total= -3.2568
# 975 long from 259.5557 ... total= -3.1525
# 976 short from 259.5557 ... total= -3.1525
# 977 long from 259.65 ... total= -3.2468
# 978 short from 259.535 ... total= -3.3618
# 979 long from 259.8 ... total= -3.6268
# 980 short from 259.75 ... total= -3.6768
# 981 long from 259.8 ... total= -3.7268
# 982 short from 259.65 ... total= -3.8768
# 983 long from 259.99 ... total= -4.2168
# 984 short from 259.76 ... total= -4.4468
# 985 long from 260.02 ... total= -4.7068
# 986 short from 259.92 ... total= -4.8068
# 987 long from 260.068 ... total= -4.9548
# 988 short from 260.0284 ... total= -4.9944
# 989 long from 260.23 ... total= -5.196
# 990 short from 260.14 ... total= -5.286
# 991 long from 260.2701 ... total= -5.4161
# 992 short from 260.2 ... total= -5.4862
# 993 long from 260.0 ... total= -5.2862
# 994 short from 260.03 ... total= -5.2562
# 995 long from 260.215 ... total= -5.4412
# 996 short from 260.3 ... total= -5.3562
# 997 long from 260.26 ... total= -5.3162
# 998 short from 260.26 ... total= -5.3162
# 999 long from 260.19 ... total= -5.2462
# 1000 short from 260.26 ... total= -5.1762
# 1001 long from 260.155 ... total= -5.0712
# 1002 short from 260.235 ... total= -4.9912
# 1003 long from 260.09 ... total= -4.8462
# 1004 short from 260.09 ... total= -4.8462
# 1005 long from 259.91 ... total= -4.6662
# 1006 short from 259.85 ... total= -4.7262
# 1007 long from 259.58 ... total= -4.4562
# 1008 short from 260.06 ... total= -3.9762
# 1009 long from 259.91 ... total= -3.8262
# 1010 short from 259.9004 ... total= -3.8358
# 1011 long from 259.96 ... total= -3.8954
# 1012 short from 259.725 ... total= -4.1304
# 1013 long from 259.64 ... total= -4.0454
# 1014 short from 259.76 ... total= -3.9254
# 1015 long from 259.57 ... total= -3.7354
# 1016 short from 259.6547 ... total= -3.6507
# 1017 long from 259.84 ... total= -3.836
# 1018 short from 259.75 ... total= -3.926
# 1019 long from 259.88 ... total= -4.056
# 1020 short from 259.85 ... total= -4.086
# 1021 long from 259.74 ... total= -3.976
# 1022 short from 259.65 ... total= -4.066
# 1023 long from 259.72 ... total= -4.136
# 1024 short from 259.51 ... total= -4.346
# 1025 long from 259.57 ... total= -4.406
# 1026 short from 259.65 ... total= -4.326
# 1027 long from 259.72 ... total= -4.396
# 1028 short from 260.025 ... total= -4.091
# 1029 long from 260.1416 ... total= -4.2076
# 1030 short from 260.13 ... total= -4.2192
# 1031 long from 260.063 ... total= -4.1522
# 1032 short from 259.88 ... total= -4.3352
# 1033 long from 260.01 ... total= -4.4652
# 1034 short from 259.9521 ... total= -4.5231
# 1035 long from 260.05 ... total= -4.621
# 1036 short from 260.12 ... total= -4.551
# 1037 long from 259.91 ... total= -4.341
# 1038 short from 259.91 ... total= -4.341
# 1039 long from 259.813 ... total= -4.244
# 1040 short from 259.89 ... total= -4.167
# 1041 long from 259.845 ... total= -4.122
# 1042 short from 260.0 ... total= -3.967
# 1043 long from 260.0 ... total= -3.967
# 1044 short from 259.95 ... total= -4.017
# 1045 long from 260.04 ... total= -4.107
# 1046 short from 260.0 ... total= -4.147
# 1047 long from 260.34 ... total= -4.487
# 1048 short from 260.25 ... total= -4.577
# 1049 long from 260.255 ... total= -4.582
# 1050 short from 260.39 ... total= -4.447
# 1051 long from 260.345 ... total= -4.402
# 1052 short from 260.68 ... total= -4.067
# 1053 long from 261.0 ... total= -4.387
# 1054 short from 260.98 ... total= -4.407
# 1055 long from 261.12 ... total= -4.547
# 1056 short from 261.42 ... total= -4.247
# 1057 long from 261.5 ... total= -4.327
# 1058 short from 261.52 ... total= -4.307
# 1059 long from 260.93 ... total= -3.717
# 1060 short from 261.18 ... total= -3.467
# 1061 long from 261.32 ... total= -3.607
# 1062 short from 261.39 ... total= -3.537
# 1063 long from 261.29 ... total= -3.437
# 1064 short from 261.32 ... total= -3.407
# 1065 long from 261.48 ... total= -3.567
# 1066 short from 261.4656 ... total= -3.5814
# 1067 long from 261.525 ... total= -3.6408
# 1068 short from 261.72 ... total= -3.4458
# 1069 long from 261.79 ... total= -3.5158
# 1070 short from 262.04 ... total= -3.2658
# 1071 long from 262.32 ... total= -3.5458
# 1072 short from 262.32 ... total= -3.5458
# 1073 long from 262.46 ... total= -3.6858
# 1074 short from 261.775 ... total= -4.3708
# 1075 long from 261.6717 ... total= -4.2675
# 1076 short from 262.34 ... total= -3.5992
# 1077 long from 261.49 ... total= -2.7492
# 1078 short from 261.27 ... total= -2.9692
# 1079 long from 261.28 ... total= -2.9792
# 1080 short from 261.2 ... total= -3.0592
# 1081 long from 261.68 ... total= -3.5392
# 1082 short from 261.67 ... total= -3.5492
# 1083 long from 261.39 ... total= -3.2692
# 1084 short from 262.585 ... total= -2.0742
# 1085 long from 262.58 ... total= -2.0692
# 1086 short from 262.0 ... total= -2.6492
# 1087 long from 262.61 ... total= -3.2592
# 1088 short from 262.98 ... total= -2.8892
# 1089 long from 262.615 ... total= -2.5242
# 1090 short from 262.555 ... total= -2.5842
# 1091 long from 262.46 ... total= -2.4892
# 1092 short from 262.51 ... total= -2.4392
# 1093 long from 262.445 ... total= -2.3742
# 1094 short from 262.5299 ... total= -2.2893
# 1095 long from 262.53 ... total= -2.2894
# 1096 short from 262.3528 ... total= -2.4666
# 1097 long from 261.733 ... total= -1.8468
# 1098 short from 261.733 ... total= -1.8468
# 1099 long from 261.91 ... total= -2.0238
# 1100 short from 261.65 ... total= -2.2838
# 1101 long from 260.86 ... total= -1.4938
# 1102 short from 261.4144 ... total= -0.9394
# 1103 long from 261.21 ... total= -0.735
# 1104 short from 260.813 ... total= -1.132
# 1105 long from 260.7 ... total= -1.019
# 1106 short from 260.28 ... total= -1.439
# 1107 long from 260.61 ... total= -1.769
# 1108 short from 260.69 ... total= -1.689
# 1109 long from 260.5 ... total= -1.499
# 1110 short from 260.685 ... total= -1.314
# 1111 long from 260.75 ... total= -1.379
# 1112 short from 260.7214 ... total= -1.4076
# 1113 long from 260.32 ... total= -1.0062
# 1114 short from 260.208 ... total= -1.1182
# 1115 long from 259.85 ... total= -0.7602
# 1116 short from 259.85 ... total= -0.7602
# 1117 long from 259.95 ... total= -0.8602
# 1118 short from 259.85 ... total= -0.9602
# 1119 long from 259.86 ... total= -0.9702
# 1120 short from 259.6534 ... total= -1.1768
# 1121 long from 259.47 ... total= -0.9934
# 1122 short from 259.3111 ... total= -1.1523
# 1123 long from 259.39 ... total= -1.2312
# 1124 short from 259.2869 ... total= -1.3343
# 1125 long from 259.25 ... total= -1.2974
# 1126 short from 259.32 ... total= -1.2274
# 1127 long from 259.268 ... total= -1.1754
# 1128 short from 259.09 ... total= -1.3534
# 1129 long from 259.3351 ... total= -1.5985
# 1130 short from 259.26 ... total= -1.6736
# 1131 long from 259.4404 ... total= -1.854
# 1132 short from 259.25 ... total= -2.0444
# 1133 long from 259.2 ... total= -1.9944
# 1134 short from 259.2 ... total= -1.9944
# 1135 long from 259.2 ... total= -1.9944
# 1136 short from 259.18 ... total= -2.0144
# 1137 long from 258.915 ... total= -1.7494
# 1138 short from 259.75 ... total= -0.9144
# 1139 long from 259.81 ... total= -0.9744
# 1140 short from 259.81 ... total= -0.9744
# 1141 long from 259.84 ... total= -1.0044
# 1142 short from 259.84 ... total= -1.0044
# 1143 long from 259.7724 ... total= -0.9368
# 1144 short from 259.75 ... total= -0.9592
# 1145 long from 260.02 ... total= -1.2292
# 1146 short from 260.21 ... total= -1.0392
# 1147 long from 260.43 ... total= -1.2592
# 1148 short from 260.43 ... total= -1.2592
# 1149 long from 260.635 ... total= -1.4642
# 1150 short from 261.54 ... total= -0.5592
# 1151 long from 261.28 ... total= -0.2992
# 1152 short from 261.22 ... total= -0.3592
# 1153 long from 261.42 ... total= -0.5592
# 1154 short from 261.09 ... total= -0.8892
# 1155 long from 261.185 ... total= -0.9842
# 1156 short from 261.17 ... total= -0.9992
# 1157 long from 260.8 ... total= -0.6292
# 1158 short from 260.76 ... total= -0.6692
# 1159 long from 260.706 ... total= -0.6152
# 1160 short from 261.1 ... total= -0.2212
# 1161 long from 260.97 ... total= -0.0912
# 1162 short from 260.97 ... total= -0.0912
# 1163 long from 260.9 ... total= -0.0211999999999
# 1164 short from 260.95 ... total= 0.0288000000001
# 1165 long from 261.08 ... total= -0.1012
# 1166 short from 260.92 ... total= -0.2612
# 1167 long from 261.015 ... total= -0.3562
# 1168 short from 260.97 ... total= -0.4012
# 1169 long from 260.975 ... total= -0.4062
# 1170 short from 260.97 ... total= -0.4112
# 1171 long from 260.73 ... total= -0.1712
# 1172 short from 260.73 ... total= -0.1712
# 1173 long from 260.86 ... total= -0.3012
# 1174 short from 260.7609 ... total= -0.4003
# 1175 long from 260.5 ... total= -0.1394
# 1176 short from 260.55 ... total= -0.0893999999998
# 1177 long from 260.74 ... total= -0.2794
# 1178 short from 260.66 ... total= -0.3594
# 1179 long from 260.57 ... total= -0.2694
# 1180 short from 260.4 ... total= -0.4394
# 1181 long from 260.4499 ... total= -0.4893
# 1182 short from 260.385 ... total= -0.5542
# 1183 long from 260.495 ... total= -0.6642
# 1184 short from 260.44 ... total= -0.7192
# 1185 long from 260.6099 ... total= -0.8891
# ...
# 3723 long from 244.8 ... total= -18.209
# 3724 short from 246.19 ... total= -16.819
# 3725 long from 246.0601 ... total= -16.6891
# 3726 short from 246.195 ... total= -16.5542
# 3727 long from 246.43 ... total= -16.7892
# 3728 short from 246.3 ... total= -16.9192
# 3729 long from 246.38 ... total= -16.9992
# 3730 short from 246.38 ... total= -16.9992
# 3731 long from 246.6 ... total= -17.2192
# 3732 short from 246.55 ... total= -17.2692
# 3733 long from 245.49 ... total= -16.2092
# 3734 short from 245.49 ... total= -16.2092
# 3735 long from 245.64 ... total= -16.3592
# 3736 short from 245.65 ... total= -16.3492
# 3737 long from 245.81 ... total= -16.5092
# 3738 short from 245.63 ... total= -16.6892
# 3739 long from 245.99 ... total= -17.0492
# 3740 short from 245.72 ... total= -17.3192
# 3741 long from 245.87 ... total= -17.4692
# 3742 short from 245.8612 ... total= -17.478
# 3743 long from 245.9 ... total= -17.5168
# 3744 short from 245.9 ... total= -17.5168
# 3745 long from 245.91 ... total= -17.5268
# 3746 short from 245.65 ... total= -17.7868
# 3747 long from 245.6329 ... total= -17.7697
# 3748 short from 245.49 ... total= -17.9126
# 3749 long from 245.73 ... total= -18.1526
# 3750 short from 245.73 ... total= -18.1526
# 3751 long from 245.581 ... total= -18.0036
# 3752 short from 245.665 ... total= -17.9196
# 3753 long from 245.72 ... total= -17.9746
# 3754 short from 245.51 ... total= -18.1846
# 3755 long from 245.64 ... total= -18.3146
# 3756 short from 245.62 ... total= -18.3346
# 3757 long from 245.6 ... total= -18.3146
# 3758 short from 245.55 ... total= -18.3646
# 3759 long from 245.6575 ... total= -18.4721
# 3760 short from 245.48 ... total= -18.6496
# 3761 long from 245.58 ... total= -18.7496
# 3762 short from 245.5717 ... total= -18.7579
# 3763 long from 245.61 ... total= -18.7962
# 3764 short from 245.59 ... total= -18.8162
# 3765 long from 245.68 ... total= -18.9062
# 3766 short from 245.67 ... total= -18.9162
# 3767 long from 245.64 ... total= -18.8862
# 3768 short from 245.24 ... total= -19.2862
# 3769 long from 245.27 ... total= -19.3162
# 3770 short from 244.96 ... total= -19.6262
# 3771 long from 244.3 ... total= -18.9662
# 3772 short from 244.3 ... total= -18.9662
# 3773 long from 244.39 ... total= -19.0562
# 3774 short from 244.39 ... total= -19.0562
# 3775 long from 244.5 ... total= -19.1662
# 3776 short from 244.94 ... total= -18.7262
# 3777 long from 244.4256 ... total= -18.2118
# 3778 short from 244.56 ... total= -18.0774
# 3779 long from 244.66 ... total= -18.1774
# 3780 short from 244.89 ... total= -17.9474
# 3781 long from 244.884 ... total= -17.9414
# 3782 short from 244.9 ... total= -17.9254
# 3783 long from 244.82 ... total= -17.8454
# 3784 short from 244.82 ... total= -17.8454
# 3785 long from 244.88 ... total= -17.9054
# 3786 short from 244.92 ... total= -17.8654
# 3787 long from 244.83 ... total= -17.7754
# 3788 short from 244.8 ... total= -17.8054
# 3789 long from 244.8462 ... total= -17.8516
# 3790 short from 244.85 ... total= -17.8478
# 3791 long from 244.92 ... total= -17.9178
# 3792 short from 244.73 ... total= -18.1078
# 3793 long from 244.7 ... total= -18.0778
# 3794 short from 244.68 ... total= -18.0978
# 3795 long from 244.71 ... total= -18.1278
# 3796 short from 244.78 ... total= -18.0578
# 3797 long from 244.81 ... total= -18.0878
# 3798 short from 244.76 ... total= -18.1378
# 3799 long from 244.84 ... total= -18.2178
# 3800 short from 244.75 ... total= -18.3078
# 3801 long from 244.78 ... total= -18.3378
# 3802 short from 244.7201 ... total= -18.3977
# 3803 long from 244.8 ... total= -18.4776
# 3804 short from 244.68 ... total= -18.5976
# 3805 long from 244.8 ... total= -18.7176
# 3806 short from 244.7511 ... total= -18.7665
# 3807 long from 244.65 ... total= -18.6654
# 3808 short from 244.65 ... total= -18.6654
# 3809 long from 244.77 ... total= -18.7854
# 3810 short from 244.78 ... total= -18.7754
# 3811 long from 244.665 ... total= -18.6604
# 3812 short from 244.32 ... total= -19.0054
# 3813 long from 244.56 ... total= -19.2454
# 3814 short from 244.73 ... total= -19.0754
# 3815 long from 247.51 ... total= -21.8554
# 3816 short from 247.27 ... total= -22.0954
# 3817 long from 247.5265 ... total= -22.3519
# 3818 short from 247.05 ... total= -22.8284
# 3819 long from 245.5716 ... total= -21.35
# 3820 short from 245.7 ... total= -21.2216
# 3821 long from 245.732 ... total= -21.2536
# 3822 short from 245.36 ... total= -21.6256
# 3823 long from 244.57 ... total= -20.8356
# 3824 short from 244.065 ... total= -21.3406
# 3825 long from 244.13 ... total= -21.4056
# 3826 short from 244.06 ... total= -21.4756
# 3827 long from 243.645 ... total= -21.0606
# 3828 short from 243.52 ... total= -21.1856
# 3829 long from 244.0 ... total= -21.6656
# 3830 short from 243.61 ... total= -22.0556
# 3831 long from 244.11 ... total= -22.5556
# 3832 short from 244.17 ... total= -22.4956
# 3833 long from 244.47 ... total= -22.7956
# 3834 short from 244.78 ... total= -22.4856
# 3835 long from 244.43 ... total= -22.1356
# 3836 short from 244.285 ... total= -22.2806
# 3837 long from 244.4356 ... total= -22.4312
# 3838 short from 244.265 ... total= -22.6018
# 3839 long from 244.272 ... total= -22.6088
# 3840 short from 244.25 ... total= -22.6308
# 3841 long from 244.03 ... total= -22.4108
# 3842 short from 244.28 ... total= -22.1608
# 3843 long from 244.16 ... total= -22.0408
# 3844 short from 244.24 ... total= -21.9608
# 3845 long from 244.11 ... total= -21.8308
# 3846 short from 243.85 ... total= -22.0908
# 3847 long from 244.09 ... total= -22.3308
# 3848 short from 244.07 ... total= -22.3508
# 3849 long from 243.93 ... total= -22.2108
# 3850 short from 243.88 ... total= -22.2608
# 3851 long from 243.86 ... total= -22.2408
# 3852 short from 243.501 ... total= -22.5998
# 3853 long from 243.159 ... total= -22.2578
# 3854 short from 243.05 ... total= -22.3668
# 3855 long from 243.32 ... total= -22.6368
# 3856 short from 243.22 ... total= -22.7368
# 3857 long from 243.1644 ... total= -22.6812
# 3858 short from 243.19 ... total= -22.6556
# 3859 long from 244.37 ... total= -23.8356
# 3860 short from 244.28 ... total= -23.9256
# 3861 long from 244.3 ... total= -23.9456
# 3862 short from 244.215 ... total= -24.0306
# 3863 long from 244.28 ... total= -24.0956
# 3864 short from 243.92 ... total= -24.4556
# 3865 long from 243.65 ... total= -24.1856
# 3866 short from 243.8898 ... total= -23.9458
# 3867 long from 243.94 ... total= -23.996
# 3868 short from 243.62 ... total= -24.316
# 3869 long from 243.401 ... total= -24.097
# 3870 short from 243.455 ... total= -24.043
# 3871 long from 243.57 ... total= -24.158
# 3872 short from 243.46 ... total= -24.268
# 3873 long from 242.9 ... total= -23.708
# 3874 short from 242.97 ... total= -23.638
# 3875 long from 242.99 ... total= -23.658
# 3876 short from 242.99 ... total= -23.658
# 3877 long from 243.05 ... total= -23.718
# 3878 short from 243.13 ... total= -23.638
# 3879 long from 243.14 ... total= -23.648
# 3880 short from 243.02 ... total= -23.768
# 3881 long from 243.26 ... total= -24.008
# 3882 short from 243.08 ... total= -24.188
# 3883 long from 243.05 ... total= -24.158
# 3884 short from 243.05 ... total= -24.158
# 3885 long from 243.25 ... total= -24.358
# 3886 short from 243.3 ... total= -24.308
# 3887 long from 243.47 ... total= -24.478
# 3888 short from 243.54 ... total= -24.408
# 3889 long from 243.67 ... total= -24.538
# 3890 short from 243.54 ... total= -24.668
# 3891 long from 243.49 ... total= -24.618
# 3892 short from 243.84 ... total= -24.268
# 3893 long from 243.83 ... total= -24.258
# 3894 short from 243.837 ... total= -24.251
# 3895 long from 243.932 ... total= -24.346
# 3896 short from 243.98 ... total= -24.298
# 3897 long from 243.9384 ... total= -24.2564
# 3898 short from 243.85 ... total= -24.3448
# 3899 long from 243.89 ... total= -24.3848
# 3900 short from 243.91 ... total= -24.3648
# 3901 long from 243.78 ... total= -24.2348
# 3902 short from 243.78 ... total= -24.2348
# 3903 long from 243.56 ... total= -24.0148
# 3904 short from 242.7 ... total= -24.8748
# 3905 long from 242.67 ... total= -24.8448
# 3906 short from 243.23 ... total= -24.2848
# 3907 long from 243.0 ... total= -24.0548
# 3908 short from 243.0 ... total= -24.0548
# 3909 long from 243.16 ... total= -24.2148
# 3910 short from 243.09 ... total= -24.2848
# 3911 long from 242.97 ... total= -24.1648
# 3912 short from 243.0608 ... total= -24.074
# 3913 long from 243.1388 ... total= -24.152
# 3914 short from 243.07 ... total= -24.2208
# 3915 long from 242.91 ... total= -24.0608
# 3916 short from 243.12 ... total= -23.8508
# 3917 long from 243.17 ... total= -23.9008
# 3918 short from 243.14 ... total= -23.9308
# 3919 long from 243.08 ... total= -23.8708
# 3920 short from 242.91 ... total= -24.0408
# 3921 long from 242.95 ... total= -24.0808
# 3922 short from 242.835 ... total= -24.1958
# 3923 long from 242.92 ... total= -24.2808
# 3924 short from 242.97 ... total= -24.2308
# 3925 long from 243.0 ... total= -24.2608
# 3926 short from 242.85 ... total= -24.4108
# 3927 long from 243.055 ... total= -24.6158
# 3928 short from 243.06 ... total= -24.6108
# 3929 long from 243.165 ... total= -24.7158
# 3930 short from 243.03 ... total= -24.8508
# 3931 long from 242.78 ... total= -24.6008
# 3932 short from 242.56 ... total= -24.8208
# 3933 long from 242.775 ... total= -25.0358
# 3934 short from 242.65 ... total= -25.1608
# 3935 long from 242.68 ... total= -25.1908
# 3936 short from 242.585 ... total= -25.2858
# 3937 long from 242.74 ... total= -25.4408
# 3938 short from 242.62 ... total= -25.5608
# 3939 long from 242.785 ... total= -25.7258
# 3940 short from 243.35 ... total= -25.1608
# 3941 long from 243.16 ... total= -24.9708
# 3942 short from 243.08 ... total= -25.0508
# 3943 long from 243.1384 ... total= -25.1092
# 3944 short from 243.33 ... total= -24.9176
# 3945 long from 243.36 ... total= -24.9476
# 3946 short from 243.21 ... total= -25.0976
# 3947 long from 243.29 ... total= -25.1776
# 3948 short from 243.7083 ... total= -24.7593
# 3949 long from 243.97 ... total= -25.021
# 3950 short from 243.4573 ... total= -25.5337
# 3951 long from 241.4796 ... total= -23.556
# 3952 short from 241.4796 ... total= -23.556
# 3953 long from 242.0 ... total= -24.0764
# 3954 short from 241.64 ... total= -24.4364
# 3955 long from 240.57 ... total= -23.3664
# 3956 short from 240.66 ... total= -23.2764
# 3957 long from 240.4 ... total= -23.0164
# 3958 short from 240.4 ... total= -23.0164
# 3959 long from 240.44 ... total= -23.0564
# 3960 short from 240.37 ... total= -23.1264
# 3961 long from 240.5 ... total= -23.2564
# 3962 short from 240.5 ... total= -23.2564
# 3963 long from 240.57 ... total= -23.3264
# 3964 short from 240.482 ... total= -23.4144
# 3965 long from 240.33 ... total= -23.2624
# 3966 short from 240.37 ... total= -23.2224
# 3967 long from 240.5 ... total= -23.3524
# 3968 short from 240.5 ... total= -23.3524
# 3969 long from 240.2 ... total= -23.0524
# 3970 short from 240.27 ... total= -22.9824
# 3971 long from 239.9 ... total= -22.6124
# 3972 short from 239.9 ... total= -22.6124
# 3973 long from 239.86 ... total= -22.5724
# 3974 short from 239.84 ... total= -22.5924
# 3975 long from 239.4795 ... total= -22.2319
# 3976 short from 239.93 ... total= -21.7814
# 3977 long from 239.5 ... total= -21.3514
# 3978 short from 239.56 ... total= -21.2914
# 3979 long from 239.43 ... total= -21.1614
# 3980 short from 239.19 ... total= -21.4014
# 3981 long from 239.35 ... total= -21.5614
# 3982 short from 239.8 ... total= -21.1114
# 3983 long from 239.5992 ... total= -20.9106
# 3984 short from 239.84 ... total= -20.6698
# 3985 long from 240.12 ... total= -20.9498
# 3986 short from 240.2247 ... total= -20.8451
# 3987 long from 240.14 ... total= -20.7604
# 3988 short from 240.14 ... total= -20.7604
# 3989 long from 240.29 ... total= -20.9104
# 3990 short from 240.25 ... total= -20.9504
# 3991 long from 240.5115 ... total= -21.2119
# 3992 short from 240.5115 ... total= -21.2119
# 3993 long from 240.59 ... total= -21.2904
# 3994 short from 240.69 ... total= -21.1904
# 3995 long from 240.9 ... total= -21.4004
# 3996 short from 240.9 ... total= -21.4004
# 3997 long from 240.69 ... total= -21.1904
# 3998 short from 240.684 ... total= -21.1964
# 3999 long from 240.6 ... total= -21.1124
# 4000 short from 240.54 ... total= -21.1724
# 4001 long from 240.63 ... total= -21.2624
# 4002 short from 240.84 ... total= -21.0524
# 4003 long from 240.6 ... total= -20.8124
# 4004 short from 240.52 ... total= -20.8924
# 4005 long from 240.47 ... total= -20.8424
# 4006 short from 240.47 ... total= -20.8424
# 4007 long from 240.44 ... total= -20.8124
# 4008 short from 240.81 ... total= -20.4424
# 4009 long from 240.965 ... total= -20.5974
# 4010 short from 240.99 ... total= -20.5724
# 4011 long from 241.0299 ... total= -20.6123
# 4012 short from 241.0299 ... total= -20.6123
# 4013 long from 241.025 ... total= -20.6074
# 4014 short from 240.88 ... total= -20.7524
# 4015 long from 240.88 ... total= -20.7524
# 4016 short from 240.9 ... total= -20.7324
# 4017 long from 240.86 ... total= -20.6924
# 4018 short from 240.76 ... total= -20.7924
# 4019 long from 240.7258 ... total= -20.7582
# 4020 short from 240.76 ... total= -20.724
# 4021 long from 240.67 ... total= -20.634
# 4022 short from 240.56 ... total= -20.744
# 4023 long from 240.6 ... total= -20.784
# 4024 short from 240.6 ... total= -20.784
# 4025 long from 240.79 ... total= -20.974
# 4026 short from 240.58 ... total= -21.184
# 4027 long from 240.68 ... total= -21.284
# 4028 short from 240.68 ... total= -21.284
# 4029 long from 240.59 ... total= -21.194
# 4030 short from 240.73 ... total= -21.054
# 4031 long from 240.9038 ... total= -21.2278
# 4032 short from 240.8945 ... total= -21.2371
# 4033 long from 240.76 ... total= -21.1026
# 4034 short from 240.67 ... total= -21.1926
# 4035 long from 240.67 ... total= -21.1926
# 4036 short from 240.5 ... total= -21.3626
# 4037 long from 240.52 ... total= -21.3826
# 4038 short from 240.52 ... total= -21.3826
# 4039 long from 240.55 ... total= -21.4126
# 4040 short from 240.55 ... total= -21.4126
# 4041 long from 240.5699 ... total= -21.4325
# 4042 short from 240.46 ... total= -21.5424
# 4043 long from 240.4971 ... total= -21.5795
# 4044 short from 240.36 ... total= -21.7166
# 4045 long from 240.35 ... total= -21.7066
# 4046 short from 240.41 ... total= -21.6466
# 4047 long from 240.45 ... total= -21.6866
# 4048 short from 240.45 ... total= -21.6866
# 4049 long from 240.6 ... total= -21.8366
# 4050 short from 240.61 ... total= -21.8266
# 4051 long from 240.84 ... total= -22.0566
# 4052 short from 240.84 ... total= -22.0566
# 4053 long from 240.95 ... total= -22.1666
# 4054 short from 241.09 ... total= -22.0266
# 4055 long from 241.16 ... total= -22.0966
# 4056 short from 241.36 ... total= -21.8966
# 4057 long from 241.38 ... total= -21.9166
# 4058 short from 241.375 ... total= -21.9216
# 4059 long from 241.26 ... total= -21.8066
# 4060 short from 241.37 ... total= -21.6966
# 4061 long from 241.4046 ... total= -21.7312
# 4062 short from 241.34 ... total= -21.7958
# 4063 long from 241.3698 ... total= -21.8256
# 4064 short from 241.1 ... total= -22.0954
# 4065 long from 240.67 ... total= -21.6654
# 4066 short from 240.67 ... total= -21.6654
# 4067 long from 240.83 ... total= -21.8254
# 4068 short from 240.9226 ... total= -21.7328
# 4069 long from 241.08 ... total= -21.8902
# 4070 short from 241.03 ... total= -21.9402
# 4071 long from 241.06 ... total= -21.9702
# 4072 short from 241.05 ... total= -21.9802
# 4073 long from 241.12 ... total= -22.0502
# 4074 short from 241.2 ... total= -21.9702
# 4075 long from 241.33 ... total= -22.1002
# 4076 short from 241.35 ... total= -22.0802
# 4077 long from 241.46 ... total= -22.1902
# 4078 short from 241.505 ... total= -22.1452
# 4079 long from 241.53 ... total= -22.1702
# 4080 short from 241.4552 ... total= -22.245
# 4081 long from 240.88 ... total= -21.6698
# 4082 short from 240.95 ... total= -21.5998
# 4083 long from 241.0 ... total= -21.6498
# 4084 short from 240.93 ... total= -21.7198
# 4085 long from 240.85 ... total= -21.6398
# 4086 short from 240.86 ... total= -21.6298
# 4087 long from 241.03 ... total= -21.7998
# 4088 short from 240.84 ... total= -21.9898
# 4089 long from 240.89 ... total= -22.0398
# 4090 short from 240.89 ... total= -22.0398
# 4091 long from 240.885 ... total= -22.0348
# 4092 short from 240.885 ... total= -22.0348
# 4093 long from 240.95 ... total= -22.0998
# 4094 short from 240.86 ... total= -22.1898
# 4095 long from 240.63 ... total= -21.9598
# 4096 short from 241.06 ... total= -21.5298
# 4097 long from 241.12 ... total= -21.5898
# 4098 short from 241.17 ... total= -21.5398

# %%
# PUSHING TO LOG[] DATAFRAME

total = 0
buys = 0
sells = 0
prev = 0
trade = 0


columns = ['L/S','price_close', 'total']
log = pd.DataFrame(columns=columns)


for index, row in ohlc.iterrows():
    #every row list # buys and sells
    #print buys," long","and",sells,"short"

    if row['buy'] > 0 and buys == 0:
        buys = 1
        sells = 0
        if prev > 0: total = total - row['close'] + prev
            
        log.set_value(trade,'L/S','long')
        log.set_value(trade,'price_close',row['close'])
        log.set_value(trade,'total',total)

        prev = row['close']
        trade = trade + 1

    if row['sell'] == 1 and sells == 0:
        sells = 1
        buys = 0
        if prev > 0: total = total + row['close'] - prev
                    
        log.set_value(trade,'L/S','short')
        log.set_value(trade,'price_close',row['close'])
        log.set_value(trade,'total',total)

        prev = row['close']
        trade = trade + 1
    
log.tail(10)
#log.sort_values(by='total',ascending=0)
# Out:
#         L/S price_close    total
# 4089   long      240.89 -22.0398
# 4090  short      240.89 -22.0398
# 4091   long     240.885 -22.0348
# 4092  short     240.885 -22.0348
# 4093   long      240.95 -22.0998
# 4094  short      240.86 -22.1898
# 4095   long      240.63 -21.9598
# 4096  short      241.06 -21.5298
# 4097   long      241.12 -21.5898
# 4098  short      241.17 -21.5398

# %%
#statistics
total
# Out:
# -2.416800000001359

# %%
# get intraday min

recentlows = ohlc.resample('60T',how='min')
recentlows[["low"]].tail(5)
# Out:
#                               low
# timestamp
# 2017-11-07 09:00:00-08:00  195.60
# 2017-11-07 10:00:00-08:00  195.88
# 2017-11-07 11:00:00-08:00  195.80
# 2017-11-07 12:00:00-08:00  194.80
# 2017-11-07 13:00:00-08:00  195.56

# %%
# calc support/resistance

# %%
try:
    store = pd.HDFStore(price_path + 'Minute_Symbol_Data.h5')
    store['minute_prices'] = pxx
    store.close()
except Exception as e:
    print(e)
finally:
    pass

# %%
from IPython.display import display, HTML

df = pd.read_hdf(price_path + 'Minute_Symbol_Data.h5')
df
# df.select('AAPL', axis=0)
# display(df)
# pd.to_html(project_dir + 'test.html')

# %%
#import matplotlib.pyplot as plt   
#from mpl_finance import candlestick_ohlc

# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 9)


 
apple["close"].tail(4).plot(grid = True)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

from datetime import datetime

df = apple

trace = go.Ohlc(x=df.index,
                open=df.Open,
                high=df.High,
                low=df.Low,
                close=df.Close)
data = [trace]
py.iplot(data, filename='simple_ohlc')
